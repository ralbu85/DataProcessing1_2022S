# %% [markdown]
# ## 딕셔너리 자료형

# %%
{"a":10, "b":20}
# Out:
# {'a': 10, 'b': 20}

# %%
x={"a":10, "b":20}
print(x)
# Out:
# {'a': 10, 'b': 20}

# %% [markdown]
# ## 딕셔너리 키-값 확인

# %%
x['a']
# Out:
# 10

# %%
x['b']
# Out:
# 20

# %% [markdown]
# ## 딕셔너리 갱신, 추가, 삭제

# %%
x['c']=30
print(x)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
x['a']=15
print(x)
# Out:
# {'a': 15, 'b': 20, 'c': 30}

# %%
del x['c']
print(x)
# Out:
# {'a': 15, 'b': 20}

# %% [markdown]
# ## 키가 있는지 확인

# %%
print(x)
# Out:
# {'a': 15, 'b': 20}

# %%
'a' in x
# Out:
# True

# %%
'c' in x
# Out:
# False

# %% [markdown]
# ## 딕셔너리와 반복 (키)

# %%
for i in x:
    print(i)
# Out:
# a
# b

# %%
x.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
for i in x.keys():
    print(i)
# Out:
# a
# b

# %% [markdown]
# ## 딕셔너리와 반복 (값)

# %%
for i in x:
    print(x[i])
# Out:
# 15
# 20

# %% [markdown]
# ## 연습문제

# %% [markdown]
# ![image.png](attachment:84f343f0-e87f-436d-af27-0f2e90facadc.png)
