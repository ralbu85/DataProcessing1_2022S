# %%
import numpy as np

# %% [markdown]
# ## 1차원 벡터 인덱싱

# %%
x=np.array([0,1,2,3,4])

# %%
x[2]
# Out:
# 2

# %%
x[-1]
# Out:
# 4

# %%
x[:2]
# Out:
# array([0, 1])

# %%
x[2:]
# Out:
# array([2, 3, 4])

# %% [markdown]
# ## 다차원 벡터 인덱싱

# %%
x = np.array([[0,1,2,3],[4,5,6,7]])
x
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
x[0]
# Out:
# array([0, 1, 2, 3])

# %%
x[0][0]
# Out:
# 0

# %%
x[0,0]
# Out:
# 0

# %%
x[0,:]
# Out:
# array([0, 1, 2, 3])

# %%
x[:,0]
# Out:
# array([0, 4])

# %% [markdown]
# ## 연습문제

# %% [markdown]
# ![image.png](attachment:1d09b91b-68bc-4dcf-8d8e-b55102d59c73.png)

# %%
a>5
